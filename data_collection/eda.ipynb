# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
sns.set_theme(
    style="whitegrid"
)

# %%
df = pd.read_excel("../izto_tum_firmalar_temiz.xlsx", dtype=str)
print("veri seti özeti")
df.info()
df.head(10)
# Out:
# veri seti özeti
# <class 'pandas.DataFrame'>
# RangeIndex: 78928 entries, 0 to 78927
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Oda Sicil No     78928 non-null  str
#  1   Ticari Sicil No  78928 non-null  str
#  2   Meslek Grubu     78928 non-null  str
#  3   Nace Kodu        78928 non-null  str
#  4   Ünvanı           78928 non-null  str
#  5   İlçe             78896 non-null  str
#  6   Tescilli Adresi  78928 non-null  str
#  7   Web Adresi       22881 non-null  str
# dtypes: str(8)
# memory usage: 4.8 MB
#   Oda Sicil No Ticari Sicil No                            Meslek Grubu  \
# 0      1526751          165299  46 - POSTA VE KURYE FAALİYETLERİ GRUBU
# 1      1725701          186353  46 - POSTA VE KURYE FAALİYETLERİ GRUBU
# 2      2215581          235687  46 - POSTA VE KURYE FAALİYETLERİ GRUBU
# 3      2146561          228716  46 - POSTA VE KURYE FAALİYETLERİ GRUBU
# ...

# %%
df.nunique()
# Out:
# Oda Sicil No       78928
# Ticari Sicil No    78752
# Meslek Grubu          84
# Nace Kodu           1720
# Ünvanı             78926
# İlçe                  19
# Tescilli Adresi    66418
# Web Adresi         19667
# dtype: int64

# %%
k_df=pd.DataFrame(
    {
        "dolu satır sayısı" : df.count(),
        "benzersiz değer sayısı" : df.nunique(),
        "tekrar eden veri sayısı" : df.count() - df.nunique()
    }
)

print("veri seti benzersiz değer sayısı ve tekrar eden veri sayısı")
k_df
# Out:
# veri seti benzersiz değer sayısı ve tekrar eden veri sayısı
#                  dolu satır sayısı  benzersiz değer sayısı  \
# Oda Sicil No                 78928                   78928
# Ticari Sicil No              78928                   78752
# Meslek Grubu                 78928                      84
# Nace Kodu                    78928                    1720
# Ünvanı                       78928                   78926
# İlçe                         78896                      19
# Tescilli Adresi              78928                   66418
# Web Adresi                   22881                   19667
#
#                  tekrar eden veri sayısı
# Oda Sicil No                           0
# Ticari Sicil No                      176
# Meslek Grubu                       78844
# Nace Kodu                          77208
# Ünvanı                                 2
# İlçe                               78877
# Tescilli Adresi                    12510
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
unvan_kopyaları = df[df.duplicated(subset=["Ünvanı"],keep=False)].sort_values(by="Ünvanı")
unvan_kopyaları
# Out:
#       Oda Sicil No Ticari Sicil No  \
# 6063       1308891          144002
# 6064       1427981          155479
# 28810        72611           21326
# 28811        91071           21326
#
#                                             Meslek Grubu  \
# 6063   51 - MESLEKİ  BİLİMSEL VE TEKNİK FAALİYETLER G...
# 6064   51 - MESLEKİ  BİLİMSEL VE TEKNİK FAALİYETLER G...
# 28810  47 - BANKACILIK VE DİĞER FİNANSAL KURULUŞLAR G...
# 28811  47 - BANKACILIK VE DİĞER FİNANSAL KURULUŞLAR G...
#
#                                                Nace Kodu  \
# 6063   71.20.11 - Gıda konusunda teknik test ve anali...
# 6064   71.20.11 - Gıda konusunda teknik test ve anali...
# 28810  64.19.01 - Bankaların faaliyetleri (katılım ba...
# 28811  64.19.01 - Bankaların faaliyetleri (katılım ba...
#
#                                                   Ünvanı             İlçe  \
# 6063   DEPPO LOJİSTİK ORMAN TARIM LABORATUVAR HİZMETL...  BORNOVA
# ...

# %%
sicil_kopyaları = df[
    df.duplicated(
        subset=["Ticari Sicil No"],
        keep=False
    )
].sort_values(
    by="Ticari Sicil No"
)

display(sicil_kopyaları.
    head(10)
)
# Out:
#       Oda Sicil No Ticari Sicil No  \
# 53530      1356771            1001
# 60220      1081811            1001
# 70433       447721           10058
# 38663       760571           10058
# 50508      1366691            1066
# 28551       260801            1066
# 16890       792041             108
# 49639       467991             108
# 75315       323521           10877
# 46372       808401           10877
#
#                                             Meslek Grubu  \
# 53530          27 - ELEKTRİK TEÇHİZATI VE TESİSATI GRUBU
# 60220                     69 - YAPI KOOPERATİFLERİ GRUBU
# 70433                             71 - MÜHENDİSLİK GRUBU
# 38663                                  55 - MAKİNE GRUBU
# 50508                               43 - KONAKLAMA GRUBU
# 28551  47 - BANKACILIK VE DİĞER FİNANSAL KURULUŞLAR G...
# 16890  06 - SU ÜRÜNLERİ,BALIKÇILIK VE AV MALZEMELERİ ...
# 49639                               43 - KONAKLAMA GRUBU
# ...

# %%
df["İlçe"]=df["İlçe"].fillna("Bilinmiyor")

kopya_sayısı = df.duplicated(
    subset=["Ünvanı","Ticari Sicil No"],
    keep=False
    ).sum()

if kopya_sayısı > 0:
    df = df.drop_duplicates(subset=["Ünvanı", "Ticari Sicil No"])
print(f"Ünvan ve Ticari Sicil No alanlarında {kopya_sayısı} adet kopya veri bulunmaktadır.")
# Out:
# Ünvan ve Ticari Sicil No alanlarında 2 adet kopya veri bulunmaktadır.

# %%
plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    y="İlçe",
    order=df["İlçe"].value_counts().index[:10],
    palette="viridis"
)
plt.title("izmir - en çok firma bulunan 10 ilçe")
plt.xlabel("firma sayısı")
plt.ylabel("ilçe")  
plt.show
# Out:
# /var/folders/4h/d3h2t6r929dctjbf1p7qkyjh0000gn/T/ipykernel_24638/2925168783.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["dijital_varlıklar"]=df["Web Adresi"].notna().map( #notna() → boş mu dolu mu kontrol eder. #
    {
        True: "web sitesi var",
        False:"web sitesi yok"
        }

)
plt.figure(figsize=(8,5))
df["dijital_varlıklar"].value_counts().plot.pie(
    autopct="%1.1f%%"
)

plt.title("firma web sitesi var mı yok mu")
plt.show()

# %%
# 1. Pandas'ın otomatik numaralandırma (factorize) özelliğini kullanarak doğrudan ID sütunları oluşturalım
df['ilce_id'] = pd.factorize(df['İlçe'])[0] + 1

df['meslek_id'] = pd.factorize(df['Meslek Grubu'])[0] + 1
"""
(
    array([0, 1, 0, 2]),    # 1. eleman
    Index(['Konak', 'Bornova', 'Karşıyaka'])   # 2. eleman
)
Kutu 0 -> array([0, 1, 0, 2])
Kutu 1 -> Index(['Konak', 'Bornova', 'Karşıyaka'])

df['ilce_id'] = pd.factorize(df['İlçe'])[0] 
                =
kodlar, ilceler = pd.factorize(df['İlçe'])
df['ilce_id'] = kodlar 
"""


# 2. ID ve metin yan yanayken bunları kopyalayıp, kopyaları silelim (SQL'deki SELECT DISTINCT mantığı)
df_ilceler = df[['ilce_id', 'İlçe']]
df_ilceler = df_ilceler.drop_duplicates()
df_ilceler = df_ilceler.rename(
    columns={'İlçe': 'ilce_adi'}
)

df_meslekler = df[['meslek_id', 'Meslek Grubu']].drop_duplicates().rename(columns={'Meslek Grubu': 'meslek_adi'})

# 3. Eski uzun metin sütunlarını ana tablodan silelim
df_firmalar = df.drop(columns=['İlçe', 'Meslek Grubu'])

# Tabloların son haline göz atalım
display(df_ilceler.head(3))
display(df_firmalar.head(3))
display(df_meslekler.head(3))
# Out:
#    ilce_id         ilce_adi
# 0        1  KONAK
# 1        2  BORNOVA
# 2        3  KEMALPAŞA
#   Oda Sicil No Ticari Sicil No  \
# 0      1526751          165299
# 1      1725701          186353
# 2      2215581          235687
#
#                                            Nace Kodu  \
# 0  52.24.10 - Kara yolu taşımacılığıyla ilgili ka...
# 1  52.24.10 - Kara yolu taşımacılığıyla ilgili ka...
# 2  53.20.09 - Kurye faaliyetleri (kara, deniz ve ...
#
#                                               Ünvanı  \
# 0  A PAMUKKALE KARGO LOJİSTİK VE TAŞIMACILIK ANON...
# 1  A PAMUKKALE KARGO LOJİSTİK VE TAŞIMACILIK ANON...
# 2  ADAATA TAŞIMACILIK SANAYİ VE TİCARET LİMİTED Ş...
#
#                                      Tescilli Adresi  \
# 0   İSMET KAPTAN MAHALLESİ GAZİ BULVARI NO:95 KAT...
# 1   KARACAOĞLAN MAH KEMALPAŞA CAD NO:285/3A IŞIKK...
# 2   MEHMET AKİF ERSOY MAH. KİRAZLI CAD.  NO: 125A...
#
#                   Web Adresi dijital_varlıklar  ilce_id  meslek_id
# ...

# %%
from sqlalchemy import create_engine

# MySQL bağlantı motorunu oluşturuyoruz (Veritabanının kapısını çalıyoruz)
sifre = "change35" 

engine = create_engine(f"mysql+pymysql://root:{sifre}@127.0.0.1:3306/staj_db")

print("Veritabanına bağlanılıyor...")

"""mysql+pymysql://root:change35@127.0.0.1:3306/staj_db
│      │            │    │        │          │
│      │            │    │        │          └── Veritabanı adı
│      │            │    │        └───────────── Port
│      │            │    └────────────────────── Sunucu adresi
│      │            └─────────────────────────── Şifre
│      └──────────────────────────────────────── Kullanıcı adı
└─────────────────────────────────────────────── Veritabanı + driver
"""

# 1. İlçeler tablosunu aktarıyoruz
df_ilceler.to_sql(name='ilceler', con=engine, if_exists='replace', index=False)
print(" 'ilceler' tablosu MySQL'e başarıyla aktarıldı!")

# 2. Meslek Grupları tablosunu aktarıyoruz
df_meslekler.to_sql(name='meslek_gruplari', con=engine, if_exists='replace', index=False)
print(" 'meslek_gruplari' tablosu MySQL'e başarıyla aktarıldı!")

# 3. Güncellenmiş Ana Tabloyu aktarıyoruz
df_firmalar.to_sql(name='firmalar', con=engine, if_exists='replace', index=False)
print(" 'firmalar' ana tablosu MySQL'e başarıyla aktarıldı!")

"""
import pymysql

conn = pymysql.connect(
    host="127.0.0.1",
    user="root",
    password=sifre,
    database="staj_db"
)

cursor = conn.cursor()

# Tabloyu sil
cursor.execute("DROP TABLE IF EXISTS ilceler")

# Tekrar oluştur
cursor.execute("""
"""CREATE TABLE ilceler (
    ilce_id INT,
    ilce_adi VARCHAR(255)
)
""")
"""
# DataFrame'deki satırları ekle
for _, row in df_ilceler.iterrows():
    cursor.execute(
        """
        #INSERT INTO ilceler (ilce_id, ilce_adi)
        #VALUES (%s, %s)
        """,
        (int(row["ilce_id"]), row["ilce_adi"])
    )

conn.commit()

cursor.close()
conn.close()
"""
# Out:
# Veritabanına bağlanılıyor...
#  'ilceler' tablosu MySQL'e başarıyla aktarıldı!
#  'meslek_gruplari' tablosu MySQL'e başarıyla aktarıldı!
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[13], line 18
#      14 df_meslekler.to_sql(name='meslek_gruplari', con=engine, if_exists='replace', index=False)
#      15 print(" 'meslek_gruplari' tablosu MySQL'e başarıyla aktarıldı!")
#      16
#      17 # 3. Güncellenmiş Ana Tabloyu aktarıyoruz
# ---> 18 df_firmalar.to_sql(name='firmalar', con=engine, if_exists='replace', index=False)
#      19 print(" 'firmalar' ana tablosu MySQL'e başarıyla aktarıldı!")
#
# File ~/Desktop/staj_proje /venv/lib/python3.14/site-packages/pandas/core/generic.py:3040, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3036         3
#    3037         """  # noqa: E501
# ...
